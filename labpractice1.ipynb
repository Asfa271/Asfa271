# %% [markdown]
# <a href="https://colab.research.google.com/github/Asfa271/Asfa271/blob/main/labpractice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("i am Asfa");
# Out:
# i am Asfa

# %% [markdown]
# print("i am Areeba);

# %%
x="Asfa ia a good girl.";
y=" Areeba n Amina are good girls too !!";
z=x+y;
print(z)
# Out:
# Asfa ia a good girl. Areeba n Amina are good girls too !!

# %% [markdown]
# ![image1.jpg](data:image/jpeg;base64,...)
